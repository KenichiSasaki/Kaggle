# %%
import cv2\\
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns
import pandas as pd

train_file = pd.read_csv(r"C:\Users\unive\Documents\Kaggle\Kuzushiji_Recognition\train.csv")

unicode_chart = pd.read_csv(r"C:\Users\unive\Documents\Kaggle\Kuzushiji_Recognition\unicode_translation.csv")

# %%
test_image = cv2.imread(r"C:\Users\unive\Documents\Kaggle\Kuzushiji_Recognition\train_images\100241706_00004_2.jpg")
test_image = cv2.cvtColor(test_image, cv2.COLOR_BGR2RGB)   

fig =plt.figure(figsize=(12, 8))

ax = fig.add_subplot(1,1,1)
ax.imshow(test_image)
plt.show()

# cv2.imshow('dst_rt', test_image)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
unicode_chart.head(20)
# Out:
#     Unicode char
# 0    U+0031    1
# 1    U+0032    2
# 2    U+0034    4
# 3    U+0036    6
# 4    U+0039    9
# 5    U+003F    ?
# 6   U+2000B    𠀋
# 7   U+20D45    𠵅
# 8   U+2123D    𡈽
# 9   U+22999    𢦙
# 10  U+22CE3    𢳣
# 11  U+231C3    𣇃
# 12  U+2324A    𣉊
# 13  U+233D0    𣏐
# 14  U+23D0E    𣴎
# 15  U+241C6    𤇆
# 16  U+242CE    𤋎
# 17  U+2437D    𤍽
# 18  U+24E30    𩹵
# 19  U+24E60    𤹠
